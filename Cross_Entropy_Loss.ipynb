# %% [markdown]
# <a href="https://colab.research.google.com/github/AadityaAdh/Cross_Entropy_Loss/blob/main/Cross_Entropy_Loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# #-logx graph
#
# lets see the graph of -log(x)

# %%
path="/content/logx.png"
img=mpimg.imread(path)
plt.imshow(img)
plt.show()

# %% [markdown]
# #yaa herni ho vanae near to 0 the slope of curve is very much high and near to 1 slope of curve is not that much high
#
# so stepsize for log function near 0 is high
# and near 1 is very much less

# %% [markdown]
# #why not use for regression
# #aaba 0-1 bhada bhaira ko value ni herni ho venae
#
# regression ma prediction vanae ko thousand haru ma hunxa
#  look first in figure

# %%
path="/content/logx1.png"
img=mpimg.imread(path)
plt.imshow(img)
plt.show()

# %% [markdown]
# #so at larger values slope is zero so there is no movement
#
# sida line ko slope 0 ta hunxa ni
#
# vanae xi thulo value ko lagi ta yo aagadi paxadi katai ni janai sakdaina
# so not use when the predicted values are not in the range of 0-1

# %% [markdown]
# #Notes
#
# using watch this video for clarifaction
#
# https://www.youtube.com/watch?v=6ArSys5qHAU

# %%
path="/content/im1.JPG"
img=mpimg.imread(path)
plt.imshow(img)
plt.show()

# %%
path="/content/im2.JPG"
img=mpimg.imread(path)
plt.imshow(img)
plt.show()

# %%
path="/content/im3.JPG"
img=mpimg.imread(path)
plt.imshow(img)
plt.show()

# %%
path="/content/im4.JPG"
img=mpimg.imread(path)
plt.imshow(img)
plt.show()

# %% [markdown]
# #note
# For binary classification, where the task is to classify instances into two classes (0 or 1), you typically use Binary Cross-Entropy Loss.
#
# For multiclass classification, where there are more than two classes, you use Categorical Cross-Entropy Loss.

# %%
# Binary Cross-Entropy Loss
#binary_crossentropy_loss = tf.keras.losses.BinaryCrossentropy()

# Categorical Cross-Entropy Loss
#categorical_crossentropy_loss = tf.keras.losses.CategoricalCrossentropy()
